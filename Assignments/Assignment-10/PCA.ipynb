# %% [markdown]
# ### Task 1: Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.Type.unique()
# Out:
# array([1, 2, 3])

# %%
df.isna().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.countplot(data=df, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.histplot(data=df, x='Alcohol', kde=True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.histplot(data=df, x='Alcohol', kde=True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.set_style("whitegrid")
df.hist(figsize=(12, 10), bins=20, edgecolor="black")
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### 1. Strong Positive Correlation (Close to +1)
#
# - Phenols & Flavanoids (0.86): A strong correlation, indicating that the wines with high phenol content - tend to have high Flavanoid content.
# - Flavanoids & Dilution (0.79): A stong correlation, suggests that flavanoid concentration always - influences the wine's dilution.
# - Phenols & Dilution (0.7): A stong correlation, wines rich in phenols tend to have higher dilution - factor.
# - Proanthocyanins & Flavanoids (0.65): Indicates that flavanoids contribute significantly to proanthocyanin levels.
#
# ### 2. Strong Negative Correlation (Close to -1)
#
# - Type & Phenols (-0.72): Indicates that total phenol content varies greatly across wine types.
# - Type & Flavanoids (-0.85): Suggests that different wine types have significantly different flavanoid - levels.
# - Type & Dilution (-0.79): Dilution levels differ significantly based on wine type.
# - Type & Proline (-0.63): Different wine types have varying Proline (amino acid) levels.
#
# ### 3. Other Notable Observations
#
# - Alcohol & Color Intensity (0.55): Wines with higher alcohol content tend to have darker colors.
#
# ### Conclusion
#
# - Wine Type (Target Variable) has strong negative correlations with Flavanoids, Phenols, Dilution, and Proline, suggesting that these features play a significant role in classifying wine.
#
# - Flavanoids & Phenols are key chemical compounds affecting the wine’s properties, showing strong internal correlations.
#
# - Alcohol Content & Color Intensity are moderately related, meaning darker wines tend to have higher alcohol content.

# %% [markdown]
# ### Task 2: Dimensionality Reduction with PCA

# %%
df1 = df.iloc[:, 1:]
df1
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6        127     2.80        3.06
# 1      13.20   1.78  2.14        11.2        100     2.65        2.76
# 2      13.16   2.36  2.67        18.6        101     2.80        3.24
# 3      14.37   1.95  2.50        16.8        113     3.85        3.49
# 4      13.24   2.59  2.87        21.0        118     2.80        2.69
# ..       ...    ...   ...         ...        ...      ...         ...
# 173    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177    14.13   4.10  2.74        24.5         96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
df1 = sc.fit_transform(df1)

# %%
df1
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]], shape=(178, 13))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=13)
pca_values = pca.fit_transform(df1)
pca_values
# Out:
# array([[ 3.31675081e+00,  1.44346263e+00, -1.65739045e-01, ...,
#         -4.51563395e-01,  5.40810414e-01, -6.62386309e-02],
#        [ 2.20946492e+00, -3.33392887e-01, -2.02645737e+00, ...,
#         -1.42657306e-01,  3.88237741e-01,  3.63650247e-03],
#        [ 2.51674015e+00,  1.03115130e+00,  9.82818670e-01, ...,
#         -2.86672847e-01,  5.83573183e-04,  2.17165104e-02],
#        ...,
#        [-2.67783946e+00,  2.76089913e+00, -9.40941877e-01, ...,
#          5.12492025e-01,  6.98766451e-01,  7.20776948e-02],
#        [-2.38701709e+00,  2.29734668e+00, -5.50696197e-01, ...,
#          2.99821968e-01,  3.39820654e-01, -2.18657605e-02],
#        [-3.20875816e+00,  2.76891957e+00,  1.01391366e+00, ...,
#         -2.29964331e-01, -1.88787963e-01, -3.23964720e-01]],
#       shape=(178, 13))

# %%
var = pca.explained_variance_ratio_
var
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823, 0.04238679, 0.02680749, 0.02222153, 0.01930019,
#        0.01736836, 0.01298233, 0.00795215])

# %%
var1 = np.cumsum(np.round(var, decimals=4)*100)
var1
# Out:
# array([ 36.2 ,  55.41,  66.53,  73.6 ,  80.16,  85.1 ,  89.34,  92.02,
#         94.24,  96.17,  97.91,  99.21, 100.01])

# %%
plt.plot(var1, color='red', marker='o', linestyle='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %% [markdown]
# As depicted in the provided figure, six distinct components are necessary to attain a cumulative variance of 90%.

# %%
pca_features = pca_values[:, :6]

# %%
pca_df = pd.DataFrame(pca_features, columns=[f"PC{i+1}" for i in range(6)])

# %%
pca_df
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6
# 0    3.316751  1.443463 -0.165739 -0.215631  0.693043  0.223880
# 1    2.209465 -0.333393 -2.026457 -0.291358 -0.257655  0.927120
# 2    2.516740  1.031151  0.982819  0.724902 -0.251033 -0.549276
# 3    3.757066  2.756372 -0.176192  0.567983 -0.311842 -0.114431
# 4    1.008908  0.869831  2.026688 -0.409766  0.298458  0.406520
# ..        ...       ...       ...       ...       ...       ...
# 173 -3.370524  2.216289 -0.342570  1.058527 -0.574164  1.108788
# 174 -2.601956  1.757229  0.207581  0.349496  0.255063  0.026465
# 175 -2.677839  2.760899 -0.940942  0.312035  1.271355 -0.273068
# 176 -2.387017  2.297347 -0.550696 -0.688285  0.813955 -1.178783
# 177 -3.208758  2.768920  1.013914  0.596903 -0.895193 -0.296092
#
# [178 rows x 6 columns]

# %%
pca_df['Type'] = df['Type']
pca_df
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6  Type
# 0    3.316751  1.443463 -0.165739 -0.215631  0.693043  0.223880     1
# 1    2.209465 -0.333393 -2.026457 -0.291358 -0.257655  0.927120     1
# 2    2.516740  1.031151  0.982819  0.724902 -0.251033 -0.549276     1
# 3    3.757066  2.756372 -0.176192  0.567983 -0.311842 -0.114431     1
# 4    1.008908  0.869831  2.026688 -0.409766  0.298458  0.406520     1
# ..        ...       ...       ...       ...       ...       ...   ...
# 173 -3.370524  2.216289 -0.342570  1.058527 -0.574164  1.108788     3
# 174 -2.601956  1.757229  0.207581  0.349496  0.255063  0.026465     3
# 175 -2.677839  2.760899 -0.940942  0.312035  1.271355 -0.273068     3
# 176 -2.387017  2.297347 -0.550696 -0.688285  0.813955 -1.178783     3
# 177 -3.208758  2.768920  1.013914  0.596903 -0.895193 -0.296092     3
#
# [178 rows x 7 columns]

# %% [markdown]
# ### Task 3: Clustering with Original Data

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
inertia = []
silhouette_scores = []
for k in range(2, 10):
    clf = KMeans(n_clusters=k, random_state=42)
    clf.fit(df1)
    inertia.append(clf.inertia_)
    silhouette_scores.append(silhouette_score(df1, clf.labels_))

plt.figure(figsize=(10, 5))
plt.plot(range(2,10), inertia, marker="o", linestyle="-", color="b", label="Inertia")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(2, 10), silhouette_scores, marker="o", linestyle="-", color="g", label="Silhouette Score")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Different k values")
plt.legend()
plt.show()

# %% [markdown]
# The Elbow Method suggests that the optimal number of clusters is 3, where the inertia curve starts flattening. The Silhouette Score also supports k=3 as a good choice for clustering.

# %%
clf = KMeans(n_clusters=3, random_state=42)
clf.fit(df1)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
y_kmeans = clf.fit_predict(df1)

# %%
df_kmeans = df.copy()

# %%
df_kmeans.drop(columns=['Type'], inplace=True)

# %%
df_kmeans['Clust'] = pd.Series(y_kmeans)

# %%
df_kmeans.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  Clust
# 0           0.28             2.29   5.64  1.04      3.92     1065      2
# 1           0.26             1.28   4.38  1.05      3.40     1050      2
# 2           0.30             2.81   5.68  1.03      3.17     1185      2
# 3           0.24             2.18   7.80  0.86      3.45     1480      2
# 4           0.39             1.82   4.32  1.04      2.93      735      2

# %%
df_kmeans.plot(x='Alcohol', y='Dilution', c=df_kmeans['Clust'], kind='scatter', cmap=plt.cm.coolwarm)
plt.title('Clusters Using KMeans')
plt.show()

# %% [markdown]
# ### Task 4: Clustering with PCA Data

# %%
pca_df
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6  Type
# 0    3.316751  1.443463 -0.165739 -0.215631  0.693043  0.223880     1
# 1    2.209465 -0.333393 -2.026457 -0.291358 -0.257655  0.927120     1
# 2    2.516740  1.031151  0.982819  0.724902 -0.251033 -0.549276     1
# 3    3.757066  2.756372 -0.176192  0.567983 -0.311842 -0.114431     1
# 4    1.008908  0.869831  2.026688 -0.409766  0.298458  0.406520     1
# ..        ...       ...       ...       ...       ...       ...   ...
# 173 -3.370524  2.216289 -0.342570  1.058527 -0.574164  1.108788     3
# 174 -2.601956  1.757229  0.207581  0.349496  0.255063  0.026465     3
# 175 -2.677839  2.760899 -0.940942  0.312035  1.271355 -0.273068     3
# 176 -2.387017  2.297347 -0.550696 -0.688285  0.813955 -1.178783     3
# 177 -3.208758  2.768920  1.013914  0.596903 -0.895193 -0.296092     3
#
# [178 rows x 7 columns]

# %%
inertia_pca = []
silhouette_scores_pca = []
for k in range(2, 10):
    clf = KMeans(n_clusters=k, random_state=42)
    clf.fit(pca_df.iloc[:, :-1])
    inertia_pca.append(clf.inertia_)
    silhouette_scores_pca.append(silhouette_score(pca_df.iloc[:, :-1], clf.labels_))

plt.figure(figsize=(10, 5))
plt.plot(range(2,10), inertia_pca, marker="o", linestyle="-", color="b", label="Inertia")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(2, 10), silhouette_scores_pca, marker="o", linestyle="-", color="g", label="Silhouette Score")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score for Different k values")
plt.legend()
plt.show()

# %%
# Using k = 3 for PCA
clf = KMeans(n_clusters=3, random_state=42)
clf.fit(pca_df.iloc[:, :-1])
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
y_pca = clf.fit_predict(pca_df.iloc[:,:-1])

# %%
pca_df['Clust'] = pd.Series(y_pca)
pca_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6  Type  Clust
# 0  3.316751  1.443463 -0.165739 -0.215631  0.693043  0.223880     1      2
# 1  2.209465 -0.333393 -2.026457 -0.291358 -0.257655  0.927120     1      2
# 2  2.516740  1.031151  0.982819  0.724902 -0.251033 -0.549276     1      2
# 3  3.757066  2.756372 -0.176192  0.567983 -0.311842 -0.114431     1      2
# 4  1.008908  0.869831  2.026688 -0.409766  0.298458  0.406520     1      2

# %%
pca_df.plot(x='PC1', y='PC2', c=clf.labels_, kind='scatter', cmap=plt.cm.coolwarm)
plt.title('Clusters Using KMeans')
plt.show()

# %% [markdown]
# ### The silhouette score for the original data is 0.285, while the silhouette score for the PCA-transformed data is 0.345. Consequently, the higher silhouette score indicates a superior clustering performance. The PCA-transformed data marginally enhances the clustering quality.
